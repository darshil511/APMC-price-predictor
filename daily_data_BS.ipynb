# %%
pip install beautifulsoup4
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: beautifulsoup4 in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from beautifulsoup4) (2.5)

# %%
pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (5.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: requests in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.31.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ladan\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from requests) (2024.2.2)

# %%
from bs4 import BeautifulSoup
import requests

# %%
html_text = requests.get('https://apmcgondal.scmsolution.in/Daily_Rate.aspx').text
# print(html_text)
soup = BeautifulSoup(html_text, 'html.parser')
table = soup.find('table', class_ = 'table table-condensed')

# %%
data = []
headings = table.find_all("th")
if headings:
    heading_data = [heading.get_text(strip=True) for heading in headings]
data.append(heading_data)

# Iterate over each row in the table
for row in table.find_all("tr"):
    # Find all cells (td) in the row
    cells = row.find_all("td")
    
    # Ensure that there are cells in the row
    if cells:
        # Extract text from each cell and append to the data list
        row_data = [cell.get_text(strip=True) for cell in cells]
        data.append(row_data)

# Print the extracted data for debugging
for row in data:
    print(row)
# Out:
# ['ક્રમ', 'જણસી', 'નીચો ભાવ', 'ઉચો ભાવ', 'સામાન્ય ભાવ']
# ['1', 'કપાસ બી. ટી.', '1151', '1606', '1571']
# ['2', 'ઘઉં લોકવન', '460', '576', '546']
# ['3', 'ઘઉં ટુકડા', '470', '800', '556']
# ['4', 'મગફળી જીણી', '821', '1261', '1191']
# ['5', 'સિંગ ફાડીયા', '1041', '1651', '1391']
# ['6', 'એરંડા / એરંડી', '826', '1171', '1151']
# ['7', 'જીરૂ', '4000', '5376', '4951']
# ['8', 'વરીયાળી', '1501', '2111', '2111']
# ['9', 'ધાણા', '1000', '1501', '1451']
# ['10', 'મરચા સૂકા પટ્ટો', '901', '4301', '2701']
# ['11', 'લસણ સુકું', '1001', '2401', '1901']
# ['12', 'ડુંગળી લાલ', '71', '386', '286']
# ['13', 'અડદ', '1051', '1741', '1551']
# ['14', 'મઠ', '921', '941', '921']
# ['15', 'તુવેર', '1011', '2061', '1981']
# ['16', 'રાજગરો', '1271', '1271', '1271']
# ['17', 'રાયડો', '726', '921', '911']
# ['18', 'રાય', '861', '1261', '1150']
# ['19', 'મેથી', '901', '1401', '1201']
# ['20', 'સુરજમુખી', '671', '671', '6714']
# ['21', 'મરચા', '801', '3701', '2251']
# ['22', 'મગફળી જાડી', '711', '1311', '1221']
# ['23', 'નવા ધાણા', '1051', '2251', '1626']
# ['24', 'નવી ધાણી', '1151', '3601', '1926']
# ['25', 'સફેદ ચણા', '1121', '2351', '1501']
# ['26', 'ધાણી', '1051', '1461', '1421']
# ['27', 'મરચા સૂકા ઘોલર', '851', '6101', '2601']
# ['28', 'ડુંગળી સફેદ', '192', '244', '222']
# ['29', 'બાજરો', '371', '381', '371']
# ['30', 'જુવાર', '541', '811', '791']
# ['31', 'મકાઇ', '481', '481', '481']
# ['32', 'મગ', '1476', '1576', '1576']
# ['33', 'ચણા', '901', '1141', '1101']
# ['34', 'વાલ', '481', '1411', '1251']
# ['35', 'ચોળા / ચોળી', '1101', '1101', '1101']
# ['36', 'સોયાબીન', '700', '871', '861']
# ['37', 'રજકાનું બી', '2201', '2201', '2201']

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(data)
df.columns = df.iloc[0]
df
# Out:
# 0   ક્રમ             જણસી  નીચો ભાવ  ઉચો ભાવ  સામાન્ય ભાવ
# 0   ક્રમ             જણસી  નીચો ભાવ  ઉચો ભાવ  સામાન્ય ભાવ
# 1      1     કપાસ બી. ટી.      1151     1606         1571
# 2      2        ઘઉં લોકવન       460      576          546
# 3      3        ઘઉં ટુકડા       470      800          556
# 4      4       મગફળી જીણી       821     1261         1191
# 5      5      સિંગ ફાડીયા      1041     1651         1391
# 6      6    એરંડા / એરંડી       826     1171         1151
# 7      7             જીરૂ      4000     5376         4951
# 8      8          વરીયાળી      1501     2111         2111
# 9      9             ધાણા      1000     1501         1451
# 10    10  મરચા સૂકા પટ્ટો       901     4301         2701
# 11    11        લસણ સુકું      1001     2401         1901
# 12    12       ડુંગળી લાલ        71      386          286
# 13    13              અડદ      1051     1741         1551
# 14    14               મઠ       921      941          921
# 15    15            તુવેર      1011     2061         1981
# 16    16           રાજગરો      1271     1271         1271
# 17    17            રાયડો       726      921          911
# 18    18              રાય       861     1261         1150
# 19    19             મેથી       901     1401         1201
# 20    20         સુરજમુખી       671      671         6714
# 21    21             મરચા       801     3701         2251
# 22    22       મગફળી જાડી       711     1311         1221
# 23    23         નવા ધાણા      1051     2251         1626
# 24    24         નવી ધાણી      1151     3601         1926
# 25    25         સફેદ ચણા      1121     2351         1501
# 26    26             ધાણી      1051     1461         1421
# 27    27   મરચા સૂકા ઘોલર       851     6101         2601
# 28    28      ડુંગળી સફેદ       192      244          222
# 29    29            બાજરો       371      381          371
# 30    30            જુવાર       541      811          791
# 31    31             મકાઇ       481      481          481
# 32    32               મગ      1476     1576         1576
# 33    33              ચણા       901     1141         1101
# 34    34              વાલ       481     1411         1251
# 35    35      ચોળા / ચોળી      1101     1101         1101
# 36    36          સોયાબીન       700      871          861
# 37    37       રજકાનું બી      2201     2201         2201

# %%
df = df.drop(0)
df
# Out:
# 0  ક્રમ             જણસી નીચો ભાવ ઉચો ભાવ સામાન્ય ભાવ
# 1     1     કપાસ બી. ટી.     1151    1606        1571
# 2     2        ઘઉં લોકવન      460     576         546
# 3     3        ઘઉં ટુકડા      470     800         556
# 4     4       મગફળી જીણી      821    1261        1191
# 5     5      સિંગ ફાડીયા     1041    1651        1391
# 6     6    એરંડા / એરંડી      826    1171        1151
# 7     7             જીરૂ     4000    5376        4951
# 8     8          વરીયાળી     1501    2111        2111
# 9     9             ધાણા     1000    1501        1451
# 10   10  મરચા સૂકા પટ્ટો      901    4301        2701
# 11   11        લસણ સુકું     1001    2401        1901
# 12   12       ડુંગળી લાલ       71     386         286
# 13   13              અડદ     1051    1741        1551
# 14   14               મઠ      921     941         921
# 15   15            તુવેર     1011    2061        1981
# 16   16           રાજગરો     1271    1271        1271
# 17   17            રાયડો      726     921         911
# 18   18              રાય      861    1261        1150
# 19   19             મેથી      901    1401        1201
# 20   20         સુરજમુખી      671     671        6714
# 21   21             મરચા      801    3701        2251
# 22   22       મગફળી જાડી      711    1311        1221
# 23   23         નવા ધાણા     1051    2251        1626
# 24   24         નવી ધાણી     1151    3601        1926
# 25   25         સફેદ ચણા     1121    2351        1501
# 26   26             ધાણી     1051    1461        1421
# 27   27   મરચા સૂકા ઘોલર      851    6101        2601
# 28   28      ડુંગળી સફેદ      192     244         222
# 29   29            બાજરો      371     381         371
# 30   30            જુવાર      541     811         791
# 31   31             મકાઇ      481     481         481
# 32   32               મગ     1476    1576        1576
# 33   33              ચણા      901    1141        1101
# 34   34              વાલ      481    1411        1251
# 35   35      ચોળા / ચોળી     1101    1101        1101
# 36   36          સોયાબીન      700     871         861
# 37   37       રજકાનું બી     2201    2201        2201

# %%
df[['ક્રમ', 'નીચો ભાવ', 'ઉચો ભાવ', 'સામાન્ય ભાવ']] = df[['ક્રમ', 'નીચો ભાવ', 'ઉચો ભાવ', 'સામાન્ય ભાવ']].apply(pd.to_numeric)

# %%
from matplotlib import font_manager as fm

# custom_font = fm.FontProperties(fname="E:/APMC_Project/Noto_Serif_Gujarati/static/NotoSerifGujarati-ExtraBold.ttf")

# %%
commodity_name = df['જણસી'].tolist()
print(commodity_name)
low_price = df['નીચો ભાવ'].tolist()
med_price = df['સામાન્ય ભાવ'].tolist()
high_price = df['ઉચો ભાવ'].tolist()
print(high_price)
# Out:
# ['કપાસ બી. ટી.', 'ઘઉં લોકવન', 'ઘઉં ટુકડા', 'મગફળી જીણી', 'સિંગ ફાડીયા', 'એરંડા / એરંડી', 'જીરૂ', 'વરીયાળી', 'ધાણા', 'મરચા સૂકા પટ્ટો', 'લસણ સુકું', 'ડુંગળી લાલ', 'અડદ', 'મઠ', 'તુવેર', 'રાજગરો', 'રાયડો', 'રાય', 'મેથી', 'સુરજમુખી', 'મરચા', 'મગફળી જાડી', 'નવા ધાણા', 'નવી ધાણી', 'સફેદ ચણા', 'ધાણી', 'મરચા સૂકા ઘોલર', 'ડુંગળી સફેદ', 'બાજરો', 'જુવાર', 'મકાઇ', 'મગ', 'ચણા', 'વાલ', 'ચોળા / ચોળી', 'સોયાબીન', 'રજકાનું બી']
# [1606, 576, 800, 1261, 1651, 1171, 5376, 2111, 1501, 4301, 2401, 386, 1741, 941, 2061, 1271, 921, 1261, 1401, 671, 3701, 1311, 2251, 3601, 2351, 1461, 6101, 244, 381, 811, 481, 1576, 1141, 1411, 1101, 871, 2201]

# %%
font_path = "E:/APMC_Project/NotoSerifGujarati-Black.ttf"
guj_fonts = fm.FontProperties(fname=font_path)

# %%
import numpy as np
ax = df.plot(x="જણસી", y = ['નીચો ભાવ', 'સામાન્ય ભાવ','ઉચો ભાવ'], kind='bar', figsize=(10, 10), stacked=True)

x=np.arange(len(commodity_name))
plt.xticks(x, commodity_name, fontproperties=guj_fonts)
plt.xlabel('જણસી', fontproperties=guj_fonts)
plt.ylabel('ભાવ', fontproperties=guj_fonts)
plt.title('કોમોડિટીઝના ભાવ', fontproperties=guj_fonts)
plt.legend(title='કિંમતનો પ્રકાર', title_fontproperties=guj_fonts, prop=guj_fonts)

plt.tight_layout()
plt.show()
